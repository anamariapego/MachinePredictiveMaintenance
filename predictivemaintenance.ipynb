# %% [markdown]
# # Continuidade Operacional: Projeto Preditivo de Manutenção de Máquinas
#
# <img src="https://proconcept.com.br/wp-content/uploads/2022/06/tipos-manutencao-preditiva-768x432.jpg.webp" height="200" width="400">
#
# **By:** [Ana Pinheiro](https://www.linkedin.com/in/ana-pego/)
#
# O projeto visa prever e prevenir falhas em máquinas utilizando técnicas de aprendizado de máquina. O objetivo é reduzir custos e tempo de inatividade, garantindo operações mais eficientes e sustentáveis.

# %% [markdown]
# <font size="5"><a id="sumario"><bold>Summary</bold></a></font>
# ***
# >1. [Imports](#ses1)
# >2. [Informações conjunto de dados](#ses2)
# >3. [Análise exploratória](#ses3)
# >4. [Pré-processamento dos dados](#ses4)
# >5. [Seleção das variáveis](#ses5)
# >6. [Modelo XGBoost](#ses6)
# >7. [Avaliando o modelo](#ses7)
# >8. [Conclusão](#ses8)

# %% [markdown]
# <h2><a id="ses1">Imports</a></h2>
#
# Importanção das bibliotecas necessárias para o desenvolvimento do projeto.
#
# [Voltar](#sumario)

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings
from sklearn import metrics
from IPython.display import display
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Para ignorar mensagens de alertas 
warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False

# Saída das tabelas
np.set_printoptions(threshold=None, precision=2)

# %% [markdown]
# <h2><a id="ses2">Informações do conjunto de dados</a></h2>
#
# [Voltar](#sumario)

# %% [markdown]
# O conjunto de dados para o desenvolvimento desse projeto é o [AI4I 2020 Predictive Maintenance Dataset - UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/dataset/601/ai4i+2020+predictive+maintenance+dataset). São um conjunto de dados sintético que reflete a manutenção preditiva real encontrada na indústria.
#
# O conjunto de dados consiste em 10 mil linhas e 10 colunas:
#
# * UID: identificador único;
#
# * ProductID: identificador único de produtpr consistindo em uma letra L, M ou H para baixa (50% de todos os produtos), média (30%) e alta (20%) como variantes de qualidade do produto;
#
# * Type: tipo do produto, **L** qualidade baixa, **M** qualidade média e **H** qualidade alta;
#
# * Air temperature [K]: temperatura do ar medida em Kelvin;
#
# * Process temperature [K]:  temperatura do processo, que é a temperatura associada ao processo de fabricação ou operação do produto;
#
# * Rotational speed [rpm]: velocidade de rotação, medida em rotações por minuto (RPM);
#
# * Torque [Nm]: força rotacional medido em Newton metros (Nm);
#
# * Tool wear [min]: tempo de desgaste medido em minuto;
#
# * Target: apresneta falha ou não;
#
# * Failure Type: Tipo da falha;

# %% [markdown]
# <h2><a id="ses3">Análise Exploratória</a></h2>
#
# Nessa sessão, aplicaremos técnicas de análise exploratória para compreender os dados, identificar padrões e possíveis anomalias nos dados.  Isso nos ajudará a obter insights iniciais sobre o conjunto de dados e a entender melhor suas características.
#
# [Voltar](#sumario)

# %%
# load data
dataset = pd.read_csv("./Data/predictive_maintenance.csv")
print('Dimensão dataset:', dataset.shape, '\n')
dataset.head()
# Out:
# Dimensão dataset: (10000, 10)
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
# statistical summary
dataset.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# 25%               1423.000000     33.200000        53.000000      0.000000
# 50%               1503.000000     40.100000       108.000000      0.000000
# 75%               1612.000000     46.800000       162.000000      0.000000
# max               2886.000000     76.600000       253.000000      1.000000

# %%
# checking the type of columns and null values
null_df = dataset.isnull().sum() * 100/len(dataset)

info_df = pd.DataFrame({'qtd_missing': dataset.isnull().sum(),
                       'percent_missing': null_df,
                       'dtype': dataset.dtypes}
                      ).reset_index().rename(columns={'index': 'column'})
info_df
# Out:
#                     column  qtd_missing  percent_missing    dtype
# 0                      UDI            0              0.0    int64
# 1               Product ID            0              0.0   object
# 2                     Type            0              0.0   object
# 3      Air temperature [K]            0              0.0  float64
# 4  Process temperature [K]            0              0.0  float64
# 5   Rotational speed [rpm]            0              0.0    int64
# 6              Torque [Nm]            0              0.0  float64
# 7          Tool wear [min]            0              0.0    int64
# 8                   Target            0              0.0    int64
# 9             Failure Type            0              0.0   object

# %%
qtd_product_type = dataset[['Product ID','Type']].groupby('Type').count().reset_index()

sns.set(rc={'figure.figsize':(5,6)})
colors = sns.color_palette('pastel')
g = plt.pie(x=qtd_product_type['Product ID'],
    labels=qtd_product_type['Type'],colors = colors, autopct='%.1f%%')

plt.title("Machine Type Percentage")
plt.show()

# %% [markdown]
# <span style="color: #cca002">Obs:</span> No gráfico **Machine Type Percentage** observa-se que o tipo de máquina mais frequente no conjunto de dados é o tipo ***L***, seguido por ***M*** e ***H***. Lembrando que as letras representam a qualidade dos produtos, issi siganifica que 60% dos produtos correspondem aos produtos de baixa qualidade.

# %%
print('Analyzing the main machine failures:')
print(50*'-')
print('\nNumber of failed and non-failed machines:\n0 - No Failure\n1 - Failure')
target = dataset[['Product ID', 'Target']].groupby('Target', as_index=False).count().rename(columns={'Product ID': 'Count'})
display(target)

print(50*'-')
print('\nFrequency of failure type:')
type_failure = dataset[['Failure Type', 'Target']].groupby('Failure Type', as_index=False).count().sort_values('Target', ascending=False).reset_index() \
                        .rename(columns={'Target': 'Count'})
display(type_failure)

print(50*'-')

qtd_failure = dataset[['Target','Failure Type']].loc[(dataset['Failure Type'] != 'No Failure')
                                                   ].groupby('Failure Type').count().reset_index()

sns.set(rc={'figure.figsize':(5,6)})
colors = sns.color_palette('pastel')
g = plt.pie(x=qtd_failure['Target'],
    labels=qtd_failure['Failure Type'],colors = colors, autopct='%.1f%%')

plt.title("Machine Failure Type Percentage")

plt.show()
# Out:
# Analyzing the main machine failures:
# --------------------------------------------------
#
# Number of failed and non-failed machines:
# 0 - No Failure
# 1 - Failure
#    Target  Count
# 0       0   9661
# 1       1    339
# --------------------------------------------------
#
# Frequency of failure type:
#    index              Failure Type  Count
# 0      1                No Failure   9652
# 1      0  Heat Dissipation Failure    112
# 2      3             Power Failure     95
# 3      2        Overstrain Failure     78
# 4      5         Tool Wear Failure     45
# 5      4           Random Failures     18
# --------------------------------------------------

# %% [markdown]
# <span style="color: #cca002">Obs:</span> No gráfico **Machine Failure Type Percentage**, não foram incluídas as máquinas que não apresentaram falha, uma vez que representam 96% do conjunto de dados. O objetivo do gráfico é analisar as falhas mais comum entre as máquinas.
#
# Observa-se que o tipo de falha mais comum é relacionados à ***dissipação de calor***, enquanto a menos comum é classificado como ***aleatótio***. Normalmente, as falhas são caracterizadas por algum tipo específicos, o que pode fornecer insights valiosos sobre os problemas enfrentados pelas máquinas.
#
# Outro ponto importante de onserva na terceira tabela é que no conjunto de dados apresenta algumas máquinas com o target/status com falha mas no tipo indica que não tem falha. Esses exemplos podem confundir o modelo, sendo target indicando falha e o tipo indicando que não há falha então esses exemplos serão removidos do conjunto de dados.

# %%
print('\nClassification of failed machine but no failure of failure type:')
countnofailure = dataset.query("Target == 1 and `Failure Type` == 'No Failure'")[['Failure Type', 'Target']] 

display(countnofailure)

print(30*'-')
print('\nMachine classification without failure but with failure type:')
countfailure = dataset.query("Target == 0 and `Failure Type` != 'No Failure'")[['Failure Type', 'Target']] 

display(countfailure)
# Out:
# Classification of failed machine but no failure of failure type:
#      Failure Type  Target
# 1437   No Failure       1
# 2749   No Failure       1
# 4044   No Failure       1
# 4684   No Failure       1
# 5536   No Failure       1
# 5941   No Failure       1
# 6478   No Failure       1
# 8506   No Failure       1
# 9015   No Failure       1
# ------------------------------
#
# Machine classification without failure but with failure type:
#          Failure Type  Target
# 1221  Random Failures       0
# 1302  Random Failures       0
# 1748  Random Failures       0
# 2072  Random Failures       0
# 2559  Random Failures       0
# 3065  Random Failures       0
# 3452  Random Failures       0
# 5471  Random Failures       0
# 5489  Random Failures       0
# 5495  Random Failures       0
# 5509  Random Failures       0
# 5553  Random Failures       0
# 5639  Random Failures       0
# 6091  Random Failures       0
# 6913  Random Failures       0
# 6960  Random Failures       0
# 7488  Random Failures       0
# 7868  Random Failures       0

# %% [markdown]
# <span style="color: #cca002">Obs:</span> Observa-se que nas tabelas acima, há máquinas classificadas com falha no campo alvo (Target), porém o tipo de falha, no campo (Failure Type), indica que não há falha, e vice-versa, com máquinas classificadas sem falhas e com o tipo de falha especificado. Esses exemplos podem confundir o modelo, pois o alvo indica falha enquanto o tipo indica que não há falha. Portanto, esses exemplos serão removidos do conjunto de dados.

# %%
columns_number = dataset.drop(columns=['Target', 'UDI']).select_dtypes(exclude=['object']).columns

plt.figure(figsize=(25, 50))
sns.set_style("white")
col_count = 1

for col in columns_number[:10]:
    plt.subplot(8, 2, col_count)
    sns.histplot(x=dataset[col], kde=False, bins=10, color='#a1c9f4')
    
    plt.title(f'Histogram {col}')
    plt.xlabel('')
    plt.ylabel('')

    col_count += 1

sns.despine()

# %% [markdown]
# <span style="color: #cca002">Obs:</span> Nos gráficos de distribuição, observa-se que as variáveis numéricas - **Air temperature [K], Process temperature [K], Rotational speed [rpm], Torque [Nm]** - apresentam uma distribuição normal. Isso significa que a maioria dos dados se concentra em torno da média, com a frequência diminuindo à medida que nos afastamos da média para ambos os lados, formando uma curva em forma de sino.

# %%
columns_number = dataset.drop(columns=['Target', 'UDI']).select_dtypes(exclude=['object']).columns

plt.figure(figsize=(25, 50))
sns.set_style("white")
col_count = 1

for col in columns_number[:10]:
    plt.subplot(8, 2, col_count)
    sns.boxplot(x=dataset[col], color='#a1c9f4')
    
    plt.title(f'BoxPlot {col}')
    plt.xlabel('')
    plt.ylabel('')

    col_count += 1

sns.despine()
plt.show()

# %% [markdown]
# <span style="color: #cca002">Obs:</span> Nos gráficos de boxplot, observa-se que algumas variáveis apresentam a presença de valores extremos ou **outliers**. Esses valores destacam-se significativamente da maioria dos dados  em termo de magnitude, como é o caso das variáveis **Rotational speed [rpm]** e **Torque [Nm]**.

# %%
sns.set_style("white")
sns.relplot(data=dataset, x="Torque [Nm]", y="Rotational speed [rpm]", hue="Failure Type",col="Type",palette='pastel');
plt.suptitle("Relação entre Torque e Velocidade de Rotação por Tipo de Produto", y=1.08)
sns.despine()
plt.show()

# %% [markdown]
# <h2><a id="ses4">Pré-Processamento dos Dados</a></h2>
#
# Nessa seção, aplicaremos técnicas de pré-porcessamento no conjunto de dados com o objetivo de prepara os dados em um formato adequado para o modelo.
#
# [Voltar](#sumario)

# %%
# removing characters not relevant columns name
def rename_coll(x:pd.DataFrame) -> pd.DataFrame: 
    x.columns=x.columns.str.replace(r'\s*\[.*?\]\s*', '', regex=True).str.title().str.replace(' ', '')
    
rename_coll(dataset)

# %%
# the ProductId column has the product type in its values, which is not necessary because in dataset it 
# has a column with product type

# remove type
dataset['ProductId'] = dataset['ProductId'].apply(lambda x: x[1:])
dataset['ProductId'] = pd.to_numeric(dataset['ProductId'])

# %%
# remove column UDI
dataset.drop(columns=['Udi'], axis=1, inplace=True)

# %%
# remove data with contradictory target and failure type variables
dataset.drop(dataset[(dataset['Target'] == 1) & (dataset['FailureType'] == 'No Failure')].index, inplace=True)
dataset.drop(dataset[(dataset['Target'] == 0) & (dataset['FailureType'] != 'No Failure')].index, inplace=True)

# %% [markdown]
# ####  Enconding

# %%
# enconding in variable categoria ordering
code_type = {'L': 0, 'M': 1,  'H': 2}

dataset['Type'] = dataset['Type'].map(code_type)

# enconding in variable categoria not ordering
code_failure = {'No Failure': 0,'Heat Dissipation Failure': 1,'Power Failure': 2,'Overstrain Failure': 3,
                'Tool Wear Failure': 4}

dataset['FailureType'] = dataset['FailureType'].map(code_failure)

# %%
print('Correlation')
dataset.corr().style.background_gradient(cmap='coolwarm')
# Out:
# Correlation
# <style type="text/css">
# #T_9828c_row0_col0, #T_9828c_row1_col1, #T_9828c_row2_col2, #T_9828c_row3_col3, #T_9828c_row4_col4, #T_9828c_row5_col5, #T_9828c_row6_col6, #T_9828c_row7_col7, #T_9828c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9828c_row0_col1, #T_9828c_row1_col0, #T_9828c_row1_col2, #T_9828c_row1_col3, #T_9828c_row1_col6, #T_9828c_row1_col8, #T_9828c_row4_col5, #T_9828c_row4_col7, #T_9828c_row5_col2, #T_9828c_row5_col3, #T_9828c_row5_col4, #T_9828c_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9828c_row0_col2, #T_9828c_row4_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_9828c_row0_col3, #T_9828c_row3_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9828c_row0_col4, #T_9828c_row0_col5, #T_9828c_row1_col5, #T_9828c_row3_col0, #T_9828c_row6_col4, #T_9828c_row6_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_9828c_row0_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9828c_row0_col7, #T_9828c_row0_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9828c_row1_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_9828c_row1_col7, #T_9828c_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9828c_row2_col0, #T_9828c_row7_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9828c_row2_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_9828c_row2_col3, #T_9828c_row3_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_9828c_row2_col4, #T_9828c_row3_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_9828c_row2_col5, #T_9828c_row3_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_9828c_row2_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9828c_row2_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9828c_row2_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9828c_row3_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_9828c_row3_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_9828c_row3_col8, #T_9828c_row8_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_9828c_row4_col0, #T_9828c_row6_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_9828c_row4_col1, #T_9828c_row5_col0, #T_9828c_row5_col1, #T_9828c_row6_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_9828c_row4_col3, #T_9828c_row8_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_9828c_row4_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_9828c_row5_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_9828c_row5_col8, #T_9828c_row6_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_9828c_row6_col2, #T_9828c_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9828c_row6_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_9828c_row7_col0, #T_9828c_row8_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_9828c_row7_col1, #T_9828c_row8_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_9828c_row7_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9828c_row7_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9828c_row7_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_9828c_row7_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_9828c_row7_col8, #T_9828c_row8_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_9828c_row8_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9828c_row8_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_9828c_row8_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9828c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9828c_level0_col0" class="col_heading level0 col0" >ProductId</th>
#       <th id="T_9828c_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_9828c_level0_col2" class="col_heading level0 col2" >AirTemperature</th>
#       <th id="T_9828c_level0_col3" class="col_heading level0 col3" >ProcessTemperature</th>
#       <th id="T_9828c_level0_col4" class="col_heading level0 col4" >RotationalSpeed</th>
#       <th id="T_9828c_level0_col5" class="col_heading level0 col5" >Torque</th>
#       <th id="T_9828c_level0_col6" class="col_heading level0 col6" >ToolWear</th>
#       <th id="T_9828c_level0_col7" class="col_heading level0 col7" >Target</th>
#       <th id="T_9828c_level0_col8" class="col_heading level0 col8" >FailureType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9828c_level0_row0" class="row_heading level0 row0" >ProductId</th>
#       <td id="T_9828c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9828c_row0_col1" class="data row0 col1" >-0.752444</td>
#       <td id="T_9828c_row0_col2" class="data row0 col2" >0.023092</td>
#       <td id="T_9828c_row0_col3" class="data row0 col3" >0.063219</td>
#       <td id="T_9828c_row0_col4" class="data row0 col4" >0.003476</td>
#       <td id="T_9828c_row0_col5" class="data row0 col5" >0.000093</td>
#       <td id="T_9828c_row0_col6" class="data row0 col6" >0.004961</td>
#       <td id="T_9828c_row0_col7" class="data row0 col7" >0.028414</td>
#       <td id="T_9828c_row0_col8" class="data row0 col8" >0.032596</td>
#     </tr>
#     <tr>
#       <th id="T_9828c_level0_row1" class="row_heading level0 row1" >Type</th>
#       <td id="T_9828c_row1_col0" class="data row1 col0" >-0.752444</td>
#       <td id="T_9828c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9828c_row1_col2" class="data row1 col2" >-0.015252</td>
#       <td id="T_9828c_row1_col3" class="data row1 col3" >-0.011988</td>
#       <td id="T_9828c_row1_col4" class="data row1 col4" >-0.003874</td>
#       <td id="T_9828c_row1_col5" class="data row1 col5" >-0.002970</td>
#       <td id="T_9828c_row1_col6" class="data row1 col6" >-0.005616</td>
#       <td id="T_9828c_row1_col7" class="data row1 col7" >-0.038448</td>
#       <td id="T_9828c_row1_col8" class="data row1 col8" >-0.037361</td>
#     </tr>
#     <tr>
#       <th id="T_9828c_level0_row2" class="row_heading level0 row2" >AirTemperature</th>
#       <td id="T_9828c_row2_col0" class="data row2 col0" >0.023092</td>
#       <td id="T_9828c_row2_col1" class="data row2 col1" >-0.015252</td>
#       <td id="T_9828c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9828c_row2_col3" class="data row2 col3" >0.876068</td>
#       <td id="T_9828c_row2_col4" class="data row2 col4" >0.023332</td>
#       <td id="T_9828c_row2_col5" class="data row2 col5" >-0.014553</td>
#       <td id="T_9828c_row2_col6" class="data row2 col6" >0.014370</td>
#       <td id="T_9828c_row2_col7" class="data row2 col7" >0.083066</td>
#       <td id="T_9828c_row2_col8" class="data row2 col8" >0.037204</td>
#     </tr>
#     <tr>
#       <th id="T_9828c_level0_row3" class="row_heading level0 row3" >ProcessTemperature</th>
#       <td id="T_9828c_row3_col0" class="data row3 col0" >0.063219</td>
#       <td id="T_9828c_row3_col1" class="data row3 col1" >-0.011988</td>
#       <td id="T_9828c_row3_col2" class="data row3 col2" >0.876068</td>
#       <td id="T_9828c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9828c_row3_col4" class="data row3 col4" >0.020200</td>
#       <td id="T_9828c_row3_col5" class="data row3 col5" >-0.015275</td>
#       <td id="T_9828c_row3_col6" class="data row3 col6" >0.013970</td>
#       <td id="T_9828c_row3_col7" class="data row3 col7" >0.035997</td>
#       <td id="T_9828c_row3_col8" class="data row3 col8" >0.018706</td>
#     </tr>
#     <tr>
#       <th id="T_9828c_level0_row4" class="row_heading level0 row4" >RotationalSpeed</th>
#       <td id="T_9828c_row4_col0" class="data row4 col0" >0.003476</td>
#       <td id="T_9828c_row4_col1" class="data row4 col1" >-0.003874</td>
#       <td id="T_9828c_row4_col2" class="data row4 col2" >0.023332</td>
#       <td id="T_9828c_row4_col3" class="data row4 col3" >0.020200</td>
#       <td id="T_9828c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9828c_row4_col5" class="data row4 col5" >-0.875069</td>
#       <td id="T_9828c_row4_col6" class="data row4 col6" >-0.000

# %% [markdown]
# <span style="color: #cca002">Obs:</span> As variáveis *Target* e *FailureType* estão altamente correlacionadas e como são as variáveis alvos para o nosso modelo etão será feita a junção dessas variáveis e criando uma única variável.

# %%
# merge variables target
dataset['TargetFailure'] = dataset['Target'].astype('str') + '-' + dataset['FailureType'].astype('str')

# enconding in variable TargetFailure
code_failure = {'0-0': 0,'1-1': 1,'1-2': 2,'1-3': 3,'1-4': 4}

dataset['TargetFailure'] = dataset['TargetFailure'].map(code_failure)

# %% [markdown]
# <h2><a id="ses5">Seleção das variáveis</a></h2>
#
# Nessa seção, serão selecionadas as variávies para o modelo e e realizada a separação dos dados em conjuntos de treino e teste.
#
# [Voltar](#sumario)

# %%
# select variables
dataset = dataset.drop(columns=['ProductId', 'Target', 'FailureType'])

# %%
# variable target 
target = dataset[['TargetFailure']]
subset = dataset.drop(columns = ['TargetFailure'])

# %%
# train and test
X_train, X_test, y_train, y_test = train_test_split(subset,target,  test_size = 0.30, random_state=123)

# %%
print(f'Train data - X: {X_train.shape[0]}')
print(f'Test data - X: {X_test.shape[0]}')
print(25*"-")
print(f'Train data - y: {y_train.shape[0]}')
print(f'Test data - y: {y_test.shape[0]}')
# Out:
# Train data - X: 6981
# Test data - X: 2992
# -------------------------
# Train data - y: 6981
# Test data - y: 2992

# %% [markdown]
# <h2><a id="ses6">Modelo XGBoost (Extreme Gradient Boosting)</a></h2>
#
# [XGBoost](https://xgboost.readthedocs.io/en/stable/) é uma biblioteca de apresndizado de máquina escalonávle e distribuída de árvores de decisão com gradiente reforçado. Ela é projetada para ser altamente eficiente , flexível e portátil.
#
#
# [Voltar](#sumario)

# %%
# model
xgb = XGBClassifier(booster='gbtree',
                    n_estimators = 100,
                    max_depth = 5,
                    learning_rate = 0.05,
                    subsample = 0.8,
                    objective='multi:softmax',
                    num_class=4,
                    random_state=0)

# %%
# training model
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None, num_class=4,
#               num_parallel_tree=None, ...)

# %%
# predict data
y_pred = xgb.predict(X_test)

# %% [markdown]
# <h2><a id="ses7">Avaliando o modelo</a></h2>
#
# [Voltar](#sumario)

# %%
# plot model tree - for a better preview, double click on the graph
fig, ax = plt.subplots(figsize=(50, 100)) 
plot_tree(xgb, ax=ax,  rankdir='LR') 
plt.show()

# %%
# values confusion matrix
matrix = confusion_matrix(y_test, y_pred)

matrix_df = pd.DataFrame(matrix,
                     index = ['No Failure','Heat Dissipation Failure','Power Failure', 'Overstrain Failure', 'Tool Wear Failure'], 
                     columns = ['No Failure','Heat Dissipation Failure','Power Failure', 'Overstrain Failure', 'Tool Wear Failure'])

matrix_df
# Out:
#                           No Failure  Heat Dissipation Failure  Power Failure  \
# No Failure                      2883                         3              5
# Heat Dissipation Failure           5                        23              0
# Power Failure                      5                         0             17
# Overstrain Failure                 6                         0              0
# Tool Wear Failure                 15                         0              0
#
#                           Overstrain Failure  Tool Wear Failure
# No Failure                                 1                  0
# Heat Dissipation Failure                   0                  0
# Power Failure                              4                  0
# Overstrain Failure                        25                  0
# Tool Wear Failure                          0                  0

# %%
# accurary model
print(f'Accurary Model: {round(accuracy_score(y_test, y_pred)*100,3)}%')
# Out:
# Accurary Model: 98.529%

# %%
# classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2892
#            1       0.88      0.82      0.85        28
#            2       0.77      0.65      0.71        26
#            3       0.83      0.81      0.82        31
#            4       0.00      0.00      0.00        15
#
#     accuracy                           0.99      2992
#    macro avg       0.70      0.66      0.67      2992
# weighted avg       0.98      0.99      0.98      2992

# %%
# performance on training data
y_pred_train = xgb.predict(X_train)
train_accuracy = accuracy_score(y_train, y_pred_train)

#  performance on test data
y_pred_test = xgb.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

print("Performance on training data:", train_accuracy)
print("Performance on test data:", test_accuracy)
# Out:
# Performance on training data: 0.9955593754476436
# Performance on test data: 0.9852941176470589

# %%
# feature importance -  feature most frequently
importance = xgb.get_booster().get_score(importance_type='weight')

# feature name and the importance
features = [feature for feature in importance.keys()]
importances = [importance[feature] for feature in features]

# %%
# graph
importances_percentage =sorted([(imp / sum(importances)) * 100 for imp in importances])

plt.figure(figsize=(10, 6))
sns.set_style("white")
bars = plt.barh(features, importances_percentage)

for bar, importance in zip(bars, importances_percentage):
    plt.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{importance:.2f}%', 
             va='center', ha='left', color='black')

plt.gca().axes.get_xaxis().set_visible(False)
plt.ylabel('Feature')
plt.title('Featue Importance')
sns.despine()
plt.show()

# %% [markdown]
# <h2><a id="ses8">Conclusão</a></h2>
#
# [Voltar](#sumario)
#
# O **modelo XGBoost** foi configurado para lidar com um problema de **classificação multiclasse**, com quatro classes representando indicadores de falha e tipos de falhas em máquinas. Após a criação do modelo, **foi realizado o treinamento e a avaliação de seu desempenho utilizando diversas métricas**, com foco especialmente na acurácia. O modelo alcançou uma **acurácia** de **98,53%** nos dados de teste, o que demonstra sua eficácia na classificação das amostras.
#
# Além disso, houve uma **análise do desempenho do modelo** tanto nos dados de treinamento quanto nos dados de teste para avaliar a possibilidade de *overfitting* ou *underfitting*. Com valores de **99%** e **98%** respectivamente, o modelo apresentou um desempenho consistente e robusto em ambas as situações, indicando uma boa capacidade de **generalização**.
#
# Também foi realizada uma análise da **importância das variáveis** no processo de classificação. Observamos que a variável **ToolWear** (desgaste da ferramenta) foi identificada como a mais influente, seguida por **Torque** e **RotationalSpeed** (velocidade rotacional), o que está alinhado com a intuição, já que essas variáveis geralmente impactam diretamente na qualidade da produção.
#
# Em resumo, obteve-se um **modelo eficaz para o conjunto de dados em questão**. Reconhecemos que, em um cenário real, poderiam enfrentar desafios adicionais e seriam necessários mais experimentos e iterações do modelo para alcançar uma solução ainda mais refinada e adequada às necessidades específicas do problema.
