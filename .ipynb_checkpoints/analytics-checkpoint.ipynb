# %% [markdown]
# # Projeto de Manutenção Preditiva de Máquinas

# %%
# Imports
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import plotly.express as px
from matplotlib import pyplot
import warnings
from IPython.display import display

# %%
# Para ignorar mensagens de alertas 
warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False

# Saída das tabelas
np.set_printoptions(threshold=None, precision=2)

# %%
import sys # verifica ambiente
print(sys.executable)
# Out:
# C:\Users\anapi\anaconda3\envs\projetos_estudos\python.exe

# %% [markdown]
# ### Descrição dos dados

# %% [markdown]
# Como os conjuntos de dados reais de manutenção preditiva são geralmente difíceis de obter e, em particular, difíceis de publicar, os dados forncecidos pelo [repositório UCI](https://archive.ics.uci.edu/dataset/601/ai4i+2020+predictive+maintenance+dataset) são um conjunto de dados sintético que reflete a manutenção preditiva real encontrada na indústria.
#
# O conjunto de dados consiste em 10 mil linhas e 10 colunas:
#
# * UID: identificador exclusivo variando de 1 a 10.000;
#
# * ProductID: consistindo em uma letra L, M ou H para baixa (50% de todos os produtos), média (30%) e alta (20%) como variantes de qualidade do produto e um número de série específico da variante;
#
# * Air temperature [K]: gerada usando um processo de passeio aleatório posteriormente normalizado para um desvio padrão de 2 K em torno de 300 K;
#
# * Process temperature [K]: gerada usando um processo de passeio aleatório normalizado para um desvio padrão de 1 K, adicionado à temperatura do ar mais 10 K;
#
# * Rotational speed [rpm]: calculada a partir de potência de 2860 W, sobreposta a um ruído normalmente distribuído;
#
# * Torque [Nm]: os valores de torque são normalmente distribuídos em torno de 40 Nm com Ïƒ = 10 Nm e sem valores negativos;
#
# * Tool wear [min]: As variantes de qualidade H/M/L adicionam 5/3/2 minutos de desgaste da ferramenta à ferramenta utilizada no processo. e um rótulo de 'falha da máquina' que indica se a máquina falhou neste ponto de dados específico para qualquer um dos seguintes modos de falha;
#
# * Target: Falha ou Não;
#
# * Failure Type: Tipo de falha;

# %% [markdown]
# ### Análise Explortaória

# %%
# load data
dataset = pd.read_csv("./Data/predictive_maintenance.csv")
print('Dimensão dataset: ', dataset.shape)
dataset.head()
# Out:
# Dimensão dataset:  (10000, 10)
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
# checking the type of columns and null values

null_df = dataset.isnull().sum() * 100/len(dataset)

info_df = pd.DataFrame({'qtd_missing': dataset.isnull().sum(),
                       'percent_missing': null_df,
                       'dtype': dataset.dtypes}
                      ).reset_index().rename(columns={'index': 'column'})
info_df
# Out:
#                     column  qtd_missing  percent_missing    dtype
# 0                      UDI            0              0.0    int64
# 1               Product ID            0              0.0   object
# 2                     Type            0              0.0   object
# 3      Air temperature [K]            0              0.0  float64
# 4  Process temperature [K]            0              0.0  float64
# 5   Rotational speed [rpm]            0              0.0    int64
# 6              Torque [Nm]            0              0.0  float64
# 7          Tool wear [min]            0              0.0    int64
# 8                   Target            0              0.0    int64
# 9             Failure Type            0              0.0   object

# %%
# removing characters not relevant columns name

def rename_coll(x:pd.DataFrame) -> pd.DataFrame: 
    x.columns=x.columns.str.replace(r'\s*\[.*?\]\s*', '', regex=True).str.title().str.replace(' ', '')
    
rename_coll(dataset)

# %%
# the ProductId column has the product type in its values, which is not necessary because in dataset it 
# has a column with product type

# remove type
dataset['ProductId'] = dataset['ProductId'].apply(lambda x: x[1:])
dataset['ProductId'] = pd.to_numeric(dataset['ProductId'])

# %%
# remove column UDI

dataset.drop(columns=['Udi'], axis=1, inplace=True)

# %%
qtd_product_type = dataset[['ProductId','Type']].groupby('Type').count().reset_index()


sns.set(rc={'figure.figsize':(5,6)})
colors = sns.color_palette('pastel')
g = plt.pie(x=qtd_product_type['ProductId'],
    labels=qtd_product_type['Type'],colors = colors, autopct='%.1f%%')

plt.title("Machine Type Percentage")
plt.show()

# %%
print('Analyzing the main machine failures:\n')

print('Number of failed and non-failed machines:\n0 (sem falha): 1 (falha):')
target = dataset[['ProductId', 'Target']].groupby('Target', as_index=False).count()
display(target)


print('Frequency of failure type:')
type_failure = dataset[['FailureType', 'Target']].groupby('FailureType', as_index=False).count().sort_values('Target')
display(type_failure)

qtd_failure = dataset[['Target','FailureType']].loc[(dataset['FailureType'] != 'No Failure')
                                                   ].groupby('FailureType').count().reset_index()

sns.set(rc={'figure.figsize':(5,6)})
colors = sns.color_palette('pastel')
g = plt.pie(x=qtd_failure['Target'],
    labels=qtd_failure['FailureType'],colors = colors, autopct='%.1f%%')

plt.title("Machine Failure Type Percentage")

plt.show()
# Out:
# Analyzing the main machine failures:
#
# Number of failed and non-failed machines:
# 0 (sem falha): 1 (falha):
#    Target  ProductId
# 0       0       9661
# 1       1        339
# Frequency of failure type:
#                 FailureType  Target
# 4           Random Failures      18
# 5         Tool Wear Failure      45
# 2        Overstrain Failure      78
# 3             Power Failure      95
# 0  Heat Dissipation Failure     112
# 1                No Failure    9652

# %%
colors = sns.color_palette('pastel')
display(colors)
print(colors.as_hex())
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]
# ['#a1c9f4', '#ffb482', '#8de5a1', '#ff9f9b', '#d0bbff', '#debb9b', '#fab0e4', '#cfcfcf', '#fffea3', '#b9f2f0']

# %%
# 

columns_number = dataset.select_dtypes(exclude=['object']).columns

plt.figure(figsize=(25, 50))
col_count = 1

for col in columns_number[:10]:
    plt.subplot(8, 2, col_count)
    sns.histplot(x=dataset[col], kde=False, bins=10, color='#ffb482')
    
    plt.title(f'{col}')
    plt.xlabel('')
    plt.ylabel('')

    col_count += 1

plt.show()

# %%
dataset
# Out:
#       ProductId Type  AirTemperature  ProcessTemperature  RotationalSpeed  \
# 0         14860    M           298.1               308.6             1551
# 1         47181    L           298.2               308.7             1408
# 2         47182    L           298.1               308.5             1498
# 3         47183    L           298.2               308.6             1433
# 4         47184    L           298.2               308.7             1408
# ...         ...  ...             ...                 ...              ...
# 9995      24855    M           298.8               308.4             1604
# 9996      39410    H           298.9               308.4             1632
# 9997      24857    M           299.0               308.6             1645
# 9998      39412    H           299.0               308.7             1408
# 9999      24859    M           299.0               308.7             1500
#
#       Torque  ToolWear  Target FailureType
# 0       42.8         0       0  No Failure
# 1       46.3         3       0  No Failure
# 2       49.4         5       0  No Failure
# 3       39.5         7       0  No Failure
# 4       40.0         9       0  No Failure
# ...      ...       ...     ...         ...
# 9995    29.5        14       0  No Failure
# 9996    31.8        17       0  No Failure
# 9997    33.4        22       0  No Failure
# 9998    48.5        25       0  No Failure
# 9999    40.2        30       0  No Failure
#
# [10000 rows x 9 columns]

# %%
sns.relplot(data=dataset, x="Torque", y="RotationalSpeed", hue="FailureType",col="Type",palette='tab10');

# %% [markdown]
# ####  Enconding e Scaling

# %%
dataset.head()
# Out:
#    ProductId Type  AirTemperature  ProcessTemperature  RotationalSpeed  \
# 0      14860    M           298.1               308.6             1551
# 1      47181    L           298.2               308.7             1408
# 2      47182    L           298.1               308.5             1498
# 3      47183    L           298.2               308.6             1433
# 4      47184    L           298.2               308.7             1408
#
#    Torque  ToolWear  Target FailureType
# 0    42.8         0       0  No Failure
# 1    46.3         3       0  No Failure
# 2    49.4         5       0  No Failure
# 3    39.5         7       0  No Failure
# 4    40.0         9       0  No Failure

# %%
# enconding in variable categoria ordering

code_type = {'L': 0, 'M': 1,  'H': 2}

dataset['Type'] = dataset['Type'].map(code_type)

# %%
# enconding in variable categoria not ordering

code_failure = {'No Failure': 0,'Heat Dissipation Failure': 1,'Power Failure': 2,'Overstrain Failure': 3,
                'Tool Wear Failure': 4,'Random Failures': 5 }

dataset['FailureType'] = dataset['FailureType'].map(code_failure)

# %%
print('Correlation')
dataset.corr().style.background_gradient(cmap='coolwarm')
# Out:
# Correlation
# <style type="text/css">
# #T_3a641_row0_col0, #T_3a641_row1_col1, #T_3a641_row2_col2, #T_3a641_row3_col3, #T_3a641_row4_col4, #T_3a641_row5_col5, #T_3a641_row6_col6, #T_3a641_row7_col7, #T_3a641_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col1, #T_3a641_row1_col0, #T_3a641_row1_col2, #T_3a641_row1_col3, #T_3a641_row1_col6, #T_3a641_row1_col8, #T_3a641_row4_col5, #T_3a641_row4_col7, #T_3a641_row5_col2, #T_3a641_row5_col3, #T_3a641_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col2, #T_3a641_row4_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col3, #T_3a641_row3_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col4, #T_3a641_row0_col5, #T_3a641_row1_col5, #T_3a641_row3_col0, #T_3a641_row6_col4, #T_3a641_row6_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_3a641_row0_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col7, #T_3a641_row2_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3a641_row0_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_3a641_row1_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3a641_row1_col7, #T_3a641_row4_col6, #T_3a641_row4_col8, #T_3a641_row5_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_3a641_row2_col0, #T_3a641_row7_col0, #T_3a641_row7_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_3a641_row2_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_3a641_row2_col3, #T_3a641_row3_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_3a641_row2_col4, #T_3a641_row3_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_3a641_row2_col5, #T_3a641_row3_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_3a641_row2_col6, #T_3a641_row3_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3a641_row2_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_3a641_row3_col1, #T_3a641_row6_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_3a641_row3_col8, #T_3a641_row8_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3a641_row4_col0, #T_3a641_row6_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_3a641_row4_col1, #T_3a641_row5_col0, #T_3a641_row5_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3a641_row4_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3a641_row5_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3a641_row5_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3a641_row6_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3a641_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_3a641_row6_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_3a641_row6_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3a641_row7_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3a641_row7_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_3a641_row7_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3a641_row7_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_3a641_row7_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3a641_row7_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_3a641_row8_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_3a641_row8_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_3a641_row8_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3a641_row8_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_3a641_row8_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_3a641_row8_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3a641_row8_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a641">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a641_level0_col0" class="col_heading level0 col0" >ProductId</th>
#       <th id="T_3a641_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_3a641_level0_col2" class="col_heading level0 col2" >AirTemperature</th>
#       <th id="T_3a641_level0_col3" class="col_heading level0 col3" >ProcessTemperature</th>
#       <th id="T_3a641_level0_col4" class="col_heading level0 col4" >RotationalSpeed</th>
#       <th id="T_3a641_level0_col5" class="col_heading level0 col5" >Torque</th>
#       <th id="T_3a641_level0_col6" class="col_heading level0 col6" >ToolWear</th>
#       <th id="T_3a641_level0_col7" class="col_heading level0 col7" >Target</th>
#       <th id="T_3a641_level0_col8" class="col_heading level0 col8" >FailureType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a641_level0_row0" class="row_heading level0 row0" >ProductId</th>
#       <td id="T_3a641_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3a641_row0_col1" class="data row0 col1" >-0.752264</td>
#       <td id="T_3a641_row0_col2" class="data row0 col2" >0.023137</td>
#       <td id="T_3a641_row0_col3" class="data row0 col3" >0.063626</td>
#       <td id="T_3a641_row0_col4" class="data row0 col4" >0.003413</td>
#       <td id="T_3a641_row0_col5" class="data row0 col5" >0.000427</td>
#       <td id="T_3a641_row0_col6" class="data row0 col6" >0.005869</td>
#       <td id="T_3a641_row0_col7" class="data row0 col7" >0.026477</td>
#       <td id="T_3a641_row0_col8" class="data row0 col8" >0.033809</td>
#     </tr>
#     <tr>
#       <th id="T_3a641_level0_row1" class="row_heading level0 row1" >Type</th>
#       <td id="T_3a641_row1_col0" class="data row1 col0" >-0.752264</td>
#       <td id="T_3a641_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3a641_row1_col2" class="data row1 col2" >-0.015176</td>
#       <td id="T_3a641_row1_col3" class="data row1 col3" >-0.012101</td>
#       <td id="T_3a641_row1_col4" class="data row1 col4" >-0.003979</td>
#       <td id="T_3a641_row1_col5" class="data row1 col5" >-0.003097</td>
#       <td id="T_3a641_row1_col6" class="data row1 col6" >-0.007255</td>
#       <td id="T_3a641_row1_col7" class="data row1 col7" >-0.036715</td>
#       <td id="T_3a641_row1_col8" class="data row1 col8" >-0.032077</td>
#     </tr>
#     <tr>
#       <th id="T_3a641_level0_row2" class="row_heading level0 row2" >AirTemperature</th>
#       <td id="T_3a641_row2_col0" class="data row2 col0" >0.023137</td>
#       <td id="T_3a641_row2_col1" class="data row2 col1" >-0.015176</td>
#       <td id="T_3a641_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3a641_row2_col3" class="data row2 col3" >0.876107</td>
#       <td id="T_3a641_row2_col4" class="data row2 col4" >0.022670</td>
#       <td id="T_3a641_row2_col5" class="data row2 col5" >-0.013778</td>
#       <td id="T_3a641_row2_col6" class="data row2 col6" >0.013853</td>
#       <td id="T_3a641_row2_col7" class="data row2 col7" >0.082556</td>
#       <td id="T_3a641_row2_col8" class="data row2 col8" >0.040470</td>
#     </tr>
#     <tr>
#       <th id="T_3a641_level0_row3" class="row_heading level0 row3" >ProcessTemperature</th>
#       <td id="T_3a641_row3_col0" class="data row3 col0" >0.063626</td>
#       <td id="T_3a641_row3_col1" class="data row3 col1" >-0.012101</td>
#       <td id="T_3a641_row3_col2" class="data row3 col2" >0.876107</td>
#       <td id="T_3a641_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3a641_row3_col4" class="data row3 col4" >0.019277</td>
#       <td id="T_3a641_row3_col5" class="data row3 col5" >-0.014061</td>
#       <td id="T_3a641_row3_col6" class="data row3 col6" >0.013488</td>
#       <td id="T_3a641_row3_col7" class="data row3 col7" >0.035946</td>
#       <td id="T_3a641_row3_col8" class="data row3 col8" >0.026149</td>
#     </tr>
#     <tr>
#       <th id="T_3a641_level0_row4" class="row_heading level0 row4" >RotationalSpeed</th>
#       <td id="T_3a641_row4_col0" class="data row4 col0" >0.003413</td>
#       <td id="T_3a641_row4_col1" class="data row4 col1" >-0.003979</td>
#       <td id="T_3a641_row4_col2" class="data row4 col2" >0.022670</td>
#       <td id="T_3a641_row4_col3" class="data row4 col3" >0.019277</td>
#       <td id="T_3a641_row4_col4" class="data row4 col4"

# %%
from sklearn.model_selection import train_test_split

# separando a variável alvo das demais
target = dataset[['Target']]
subset = dataset.drop(columns = ['Target', 'FailureType'])

# separando os datasets em treino e teste
X_train, X_test, y_train, y_test = train_test_split(subset,target,  test_size = 0.30, random_state=0)

# verificando a dimensão dos dados de treino e teste
print(f'Dados para Treino: {X_train.shape[0]} amostras')
print(f'Dados para Teste: {X_test.shape[0]} amostras')
# Out:
# Dados para Treino: 7000 amostras
# Dados para Teste: 3000 amostras

# %%
from xgboost import XGBClassifier

# %%
clf = XGBClassifier(n_estimators = 200,
                    max_depth = 10, 
                    learning_rate = 0.01,
                    subsample = 1,
                    random_state=0)

# Training the XGB classifier
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)

# %%
# previsão dos dados
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[2890,   11],
#        [  45,   54]], dtype=int64)

# %%
# apresentando os resultados pela Matriz de Confusão

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calcula a matriz de confusão
cm = confusion_matrix(y_test, y_pred)  # Substitua 'predicted_labels' pelos rótulos previstos pelo seu modelo

# Cria o objeto ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)  # Substitua 'clf.classes_' pelos seus rótulos de classe

# Plota a matriz de confusão
disp.plot()

# Mostra o plot
plt.show()

# %%
# Acurácia 
from sklearn.metrics import accuracy_score

print(f'Precisão do modelo: {round(accuracy_score(y_test, y_pred)*100,3)}%')
# Out:
# Precisão do modelo: 98.133%

# %%
# Relatório da Classificação
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2901
#            1       0.83      0.55      0.66        99
#
#     accuracy                           0.98      3000
#    macro avg       0.91      0.77      0.82      3000
# weighted avg       0.98      0.98      0.98      3000

# %%
# Definir os conjuntos de avaliação
eval_set = [(X_train, y_train), (X_test, y_test)]

# Definir os parâmetros do modelo XGBoost
params = {
    'objective': 'multi:softmax',  # para problemas de classificação multiclasse
    'num_class': 3,                 # número de classes no conjunto de dados
    'eval_metric': 'merror',        # métrica de avaliação para otimização
    'max_depth': 3,                 # profundidade máxima da árvore
    'learning_rate': 0.1            # taxa de aprendizado
}

# Instanciar o modelo XGBoost
model = XGBClassifier(**params)

# Treinar o modelo XGBoost com os conjuntos de avaliação
model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-merror:0.02686	validation_1-merror:0.02900
# [1]	validation_0-merror:0.02686	validation_1-merror:0.02900
# [2]	validation_0-merror:0.02614	validation_1-merror:0.02767
# [3]	validation_0-merror:0.02614	validation_1-merror:0.02767
# [4]	validation_0-merror:0.02614	validation_1-merror:0.02767
# [5]	validation_0-merror:0.02571	validation_1-merror:0.02733
# [6]	validation_0-merror:0.02557	validation_1-merror:0.02733
# [7]	validation_0-merror:0.02486	validation_1-merror:0.02733
# [8]	validation_0-merror:0.02443	validation_1-merror:0.02533
# [9]	validation_0-merror:0.02457	validation_1-merror:0.02533
# [10]	validation_0-merror:0.02414	validation_1-merror:0.02500
# [11]	validation_0-merror:0.02400	validation_1-merror:0.02467
# [12]	validation_0-merror:0.02400	validation_1-merror:0.02467
# [13]	validation_0-merror:0.02386	validation_1-merror:0.02467
# [14]	validation_0-merror:0.02314	validation_1-merror:0.02433
# [15]	validation_0-merror:0.02286	validation_1-merror:0.02433
# [16]	validation_0-merror:0.02071	validation_1-merror:0.02200
# [17]	validation_0-merror:0.02057	validation_1-merror:0.02267
# [18]	validation_0-merror:0.02100	validation_1-merror:0.02267
# [19]	validation_0-merror:0.02071	validation_1-merror:0.02133
# [20]	validation_0-merror:0.02043	validation_1-merror:0.02167
# [21]	validation_0-merror:0.02029	validation_1-merror:0.02133
# [22]	validation_0-merror:0.02014	validation_1-merror:0.02133
# [23]	validation_0-merror:0.02000	validation_1-merror:0.02133
# [24]	validation_0-merror:0.02000	validation_1-merror:0.02133
# [25]	validation_0-merror:0.01957	validation_1-merror:0.02033
# [26]	validation_0-merror:0.01943	validation_1-merror:0.02033
# [27]	validation_0-merror:0.01929	validation_1-merror:0.02033
# [28]	validation_0-merror:0.01943	validation_1-merror:0.02033
# [29]	validation_0-merror:0.01914	validation_1-merror:0.02033
# [30]	validation_0-merror:0.01871	validation_1-merror:0.02067
# [31]	validation_0-merror:0.01886	validation_1-merror:0.02033
# [32]	validation_0-merror:0.01857	validation_1-merror:0.02000
# [33]	validation_0-merror:0.01843	validation_1-merror:0.01933
# [34]	validation_0-merror:0.01814	validation_1-merror:0.01933
# [35]	validation_0-merror:0.01814	validation_1-merror:0.01967
# [36]	validation_0-merror:0.01529	validation_1-merror:0.01833
# [37]	validation_0-merror:0.01557	validation_1-merror:0.01800
# [38]	validation_0-merror:0.01671	validation_1-merror:0.01833
# [39]	validation_0-merror:0.01557	validation_1-merror:0.01800
# [40]	validation_0-merror:0.01557	validation_1-merror:0.01800
# [41]	validation_0-merror:0.01514	validation_1-merror:0.01800
# [42]	validation_0-merror:0.01486	validation_1-merror:0.01800
# [43]	validation_0-merror:0.01486	validation_1-merror:0.01800
# [44]	validation_0-merror:0.01443	validation_1-merror:0.01800
# [45]	validation_0-merror:0.01443	validation_1-merror:0.01800
# [46]	validation_0-merror:0.01429	validation_1-merror:0.01800
# [47]	validation_0-merror:0.01386	validation_1-merror:0.01700
# [48]	validation_0-merror:0.01371	validation_1-merror:0.01733
# [49]	validation_0-merror:0.01386	validation_1-merror:0.01733
# [50]	validation_0-merror:0.01343	validation_1-merror:0.01733
# [51]	validation_0-merror:0.01343	validation_1-merror:0.01767
# [52]	validation_0-merror:0.01271	validation_1-merror:0.01733
# [53]	validation_0-merror:0.01243	validation_1-merror:0.01733
# [54]	validation_0-merror:0.01229	validation_1-merror:0.01733
# [55]	validation_0-merror:0.01214	validation_1-merror:0.01733
# [56]	validation_0-merror:0.01200	validation_1-merror:0.01700
# [57]	validation_0-merror:0.01186	validation_1-merror:0.01700
# [58]	validation_0-merror:0.01157	validation_1-merror:0.01733
# [59]	validation_0-merror:0.01157	validation_1-merror:0.01733
# [60]	validation_0-merror:0.01157	validation_1-merror:0.01733
# [61]	validation_0-merror:0.01157	validation_1-merror:0.01767
# [62]	validation_0-merror:0.01157	validation_1-merror:0.01767
# [63]	validation_0-merror:0.01157	validation_1-merror:0.01733
# [64]	validation_0-merror:0.01129	validation_1-merror:0.01733
# [65]	validation_0-merror:0.01086	validation_1-merror:0.01767
# [66]	validation_0-merror:0.01071	validation_1-merror:0.01767
# [67]	validation_0-merror:0.01071	validation_1-merror:0.01767
# [68]	validation_0-merror:0.01057	validation_1-merror:0.01767
# [69]	validation_0-merror:0.01057	validation_1-merror:0.01767
# [70]	validation_0-merror:0.01043	validation_1-merror:0.01767
# [71]	validation_0-merror:0.01043	validation_1-merror:0.01800
# [72]	validation_0-merror:0.01043	validation_1-merror:0.01867
# [73]	validation_0-merror:0.01043	validation_1-merror:0.01867
# [74]	validation_0-merror:0.01029	validation_1-merror:0.01867
# [75]	validation_0-merror:0.01029	validation_1-merror:0.01867
# [76]	validation_0-merror:0.01029	validation_1-merror:0.01867
# [77]	validation_0-merror:0.01029	validation_1-merror:0.01867
# [78]	validation_0-merror:0.01014	validation_1-merror:0.01867
# [79]	validation_0-merror:0.01014	validation_1-merror:0.01867
# [80]	validation_0-merror:0.01014	validation_1-merror:0.01867
# [81]	validation_0-merror:0.01029	validation_1-merror:0.01867
# [82]	validation_0-merror:0.01000	validation_1-merror:0.01867
# [83]	validation_0-merror:0.00986	validation_1-merror:0.01867
# [84]	validation_0-merror:0.00971	validation_1-merror:0.01867
# [85]	validation_0-merror:0.00957	validation_1-merror:0.01833
# [86]	validation_0-merror:0.00957	validation_1-merror:0.01833
# [87]	validation_0-merror:0.00957	validation_1-merror:0.01833
# [88]	validation_0-merror:0.00957	validation_1-merror:0.01867
# [89]	validation_0-merror:0.00957	validation_1-merror:0.01867
# [90]	validation_0-merror:0.00929	validation_1-merror:0.01867
# [91]	validation_0-merror:0.00929	validation_1-merror:0.01867
# [92]	validation_0-merror:0.00929	validation_1-merror:0.01867
# [93]	validation_0-merror:0.00943	validation_1-merror:0.01867
# [94]	validation_0-merror:0.00914	validation_1-merror:0.01867
# [95]	validation_0-merror:0.00914	validation_1-merror:0.01867
# [96]	validation_0-merror:0.00914	validation_1-merror:0.01867
# [97]	validation_0-merror:0.00929	validation_1-merror:0.01867
# [98]	validation_0-merror:0.00914	validation_1-merror:0.01867
# [99]	validation_0-merror:0.00914	validation_1-merror:0.01867
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_class=3, num_parallel_tree=None, ...)

# %%
metricas = model.evals_result()

# %%
# PCA 
# https://www.geeksforgeeks.org/principal-component-analysis-with-python/
